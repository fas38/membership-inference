# %%
import torch
from torch.utils.data import DataLoader, random_split, TensorDataset
import pickle
import torchvision
import torch.nn as nn
import torch.optim as optim
from torchvision.models import resnet34
from torchvision import transforms
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, AdaBoostClassifier, HistGradientBoostingClassifier, VotingClassifier
import xgboost as xgb
from sklearn.metrics import accuracy_score
import random
import joblib

# set random seed
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Dataset Preparation

# %%
DATA_PATH = '/content/drive/My Drive/Colab Notebooks/attack/pickle/cifar10/resnet34/shadow.p'

device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)

with open(DATA_PATH, "rb") as f:
    dataset = pickle.load(f)

print(type(dataset), len(dataset))

# split the dataset
train_size = int(0.8 * len(dataset))
test_size = len(dataset) - train_size
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# create dataloaders
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True, num_workers=2)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False, num_workers=2)
# Out:
# cuda:0
# <class 'list'> 30000

# %% [markdown]
# # shadow model

# %%
# model parameters
TARGET_MODEL_PATH = '/content/drive/My Drive/Colab Notebooks/attack/models/resnet34_cifar10.pth'
n_classes = 10
n_epochs = 50
batch_size = 64
learning_rate = 0.001
weight_decay = 1e-4  # parameter for L2 regularization

# load target model for training shadow model
shadow_model = resnet34(num_classes=n_classes).to(device)
state_dict = torch.load(TARGET_MODEL_PATH, map_location=device)
shadow_model.load_state_dict(state_dict['net'])
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(shadow_model.parameters(), lr=learning_rate, weight_decay=weight_decay)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)

# model training
shadow_model.train()
for epoch in range(n_epochs):
    running_loss = 0.0
    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = shadow_model(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    scheduler.step()

    print(f"Epoch {epoch+1}/{n_epochs}, Loss: {running_loss/len(train_loader)}")
    # save the model after each 5 epochs
    if (epoch+1) % 5 == 0:
        torch.save(shadow_model.state_dict(), f"/content/drive/My Drive/Colab Notebooks/attack/my_models/cifar10_resnet/shadow_model_epoch_{epoch+1}.pt")
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py:744: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:919.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 1/50, Loss: 0.953537145614624
# Epoch 2/50, Loss: 0.7045986836751302
# Epoch 3/50, Loss: 0.5461268642346064
# Epoch 4/50, Loss: 0.4314792303244273
# Epoch 5/50, Loss: 0.33479435177644096
# Epoch 6/50, Loss: 0.25611126454671224
# Epoch 7/50, Loss: 0.21289947843551635
# Epoch 8/50, Loss: 0.17704525246222813
# Epoch 9/50, Loss: 0.16731408825019994
# Epoch 10/50, Loss: 0.148850849678119
# Epoch 11/50, Loss: 0.063306514116625
# Epoch 12/50, Loss: 0.025057315078874428
# Epoch 13/50, Loss: 0.015103649364163477
# Epoch 14/50, Loss: 0.010856496345562239
# Epoch 15/50, Loss: 0.007141458673713108
# Epoch 16/50, Loss: 0.0059167006482991075
# Epoch 17/50, Loss: 0.004763339297535519
# Epoch 18/50, Loss: 0.0035495820069530357
# Epoch 19/50, Loss: 0.003403091239432494
# Epoch 20/50, Loss: 0.003522117187657083
# Epoch 21/50, Loss: 0.002548049951554276
# Epoch 22/50, Loss: 0.0021525892882297438
# Epoch 23/50, Loss: 0.00190366480499506
# Epoch 24/50, Loss: 0.0015825337367520358
# Epoch 25/50, Loss: 0.0017289480246060218
# Epoch 26/50, Loss: 0.0016290881546059002
# Epoch 27/50, Loss: 0.0016189594563329592
# Epoch 28/50, Loss: 0.001645094305315676
# Epoch 29/50, Loss: 0.0012159575488961613
# Epoch 30/50, Loss: 0.0013386574537532093
# Epoch 31/50, Loss: 0.0015818603550239155
# Epoch 32/50, Loss: 0.001215606715142106
# Epoch 33/50, Loss: 0.001154893549954674
# Epoch 34/50, Loss: 0.0012553192380194862
# Epoch 35/50, Loss: 0.0011192482386832125
# Epoch 36/50, Loss: 0.001368772094642433
# Epoch 37/50, Loss: 0.0011840794620414576
# Epoch 38/50, Loss: 0.0011982240934157744
# Epoch 39/50, Loss: 0.0011036146547994577
# Epoch 40/50, Loss: 0.0013012679622042924
# Epoch 41/50, Loss: 0.0012103987064717027
# Epoch 42/50, Loss: 0.0011273326988254363
# Epoch 43/50, Loss: 0.0009849061233690008
# Epoch 44/50, Loss: 0.0012377277366855803
# Epoch 45/50, Loss: 0.0012001719904559045
# Epoch 46/50, Loss: 0.0014890589872763181
# Epoch 47/50, Loss: 0.0011665256593648033
# Epoch 48/50, Loss: 0.0009710604410696153
# Epoch 49/50, Loss: 0.0011220923954970204
# Epoch 50/50, Loss: 0.0011692893135283762

# %%
# load trained shadow model
n_classes = 10
criterion = nn.CrossEntropyLoss()

shadow_model = resnet34(num_classes=n_classes).to(device)
shadow_model.load_state_dict(torch.load("/content/drive/My Drive/Colab Notebooks/attack/my_models/cifar10_resnet/shadow_model_epoch_50.pt"))
# Out:
# <All keys matched successfully>

# %%
# model evaluation
test_loss = 0.0
correct = 0
total = 0
shadow_model.eval()
with torch.no_grad():
    for inputs, labels in test_loader:
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = shadow_model(inputs)
        loss = criterion(outputs, labels)
        test_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1) # get the class index
        total += labels.size(0) # total samples
        correct += (predicted == labels).sum().item() # correctly predicted samples

print(f'Test Loss: {test_loss/len(test_loader)}, Accuracy: {100 * correct / total}%')
# Out:
# Test Loss: 1.4883059028615342, Accuracy: 73.8%

# %% [markdown]
# # Attack Model Training

# %%
# method for generating attack dataset for given model and dataset
def generate_attack_data(model, data_loader, label):
    attack_data = []
    model.eval()
    with torch.no_grad():
        for inputs, labels in data_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            probabilities = nn.functional.softmax(outputs, dim=1)
            for prob in probabilities:
                attack_data.append((prob.cpu().numpy(), label))
    return attack_data

# generate attack data
member_data = generate_attack_data(shadow_model, train_loader, 1) # member label as 1
non_member_data = generate_attack_data(shadow_model, test_loader, 0) # non-member label as 0
attack_data = member_data + non_member_data

# prepare the data for training attack model
np.random.shuffle(attack_data)
X = np.array([x[0] for x in attack_data])
y = np.array([x[1] for x in attack_data])
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=seed)

# %%
# train attack model
attack_model = xgb.XGBClassifier(
    n_estimators=500,
    max_depth=12,
    learning_rate=0.03,
    objective='binary:logistic',
    eval_metric='logloss',
    use_label_encoder=False,
    subsample=0.9,
    colsample_bytree=0.5,
    reg_alpha=0.1,
    reg_lambda=4.0,
    early_stopping_rounds=30,
    scale_pos_weight=0.2,
    tree_method = 'hist',
    device = 'gpu'
)

attack_model.fit(X_train, y_train,
                 eval_set=[(X_train, y_train), (X_test, y_test)],
                 verbose=True)

y_pred = attack_model.predict(X_train)
accuracy = accuracy_score(y_train, y_pred)
print(f"Attack Model Accuracy on train set: {accuracy}")

# evaluate the attack model on the test data
y_pred = attack_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print(f"Attack Model Accuracy on test set: {accuracy}")
# Out:
# [0]	validation_0-logloss:0.76240	validation_1-logloss:0.76629
# [1]	validation_0-logloss:0.75401	validation_1-logloss:0.75860
# [2]	validation_0-logloss:0.74580	validation_1-logloss:0.75121
# [3]	validation_0-logloss:0.73768	validation_1-logloss:0.74371
# [4]	validation_0-logloss:0.73025	validation_1-logloss:0.73708
# [5]	validation_0-logloss:0.72317	validation_1-logloss:0.73071
# [6]	validation_0-logloss:0.71590	validation_1-logloss:0.72407
# [7]	validation_0-logloss:0.70919	validation_1-logloss:0.71828
# [8]	validation_0-logloss:0.70277	validation_1-logloss:0.71243
# [9]	validation_0-logloss:0.69641	validation_1-logloss:0.70675
# [10]	validation_0-logloss:0.69049	validation_1-logloss:0.70165
# [11]	validation_0-logloss:0.68436	validation_1-logloss:0.69633
# [12]	validation_0-logloss:0.67861	validation_1-logloss:0.69123
# [13]	validation_0-logloss:0.67289	validation_1-logloss:0.68626
# [14]	validation_0-logloss:0.66704	validation_1-logloss:0.68111
# [15]	validation_0-logloss:0.66194	validation_1-logloss:0.67663
# [16]	validation_0-logloss:0.65675	validation_1-logloss:0.67222
# [17]	validation_0-logloss:0.65181	validation_1-logloss:0.66784
# [18]	validation_0-logloss:0.64670	validation_1-logloss:0.66334
# [19]	validation_0-logloss:0.64192	validation_1-logloss:0.65921
# [20]	validation_0-logloss:0.63723	validation_1-logloss:0.65532
# [21]	validation_0-logloss:0.63223	validation_1-logloss:0.65132
# [22]	validation_0-logloss:0.62783	validation_1-logloss:0.64782
# [23]	validation_0-logloss:0.62351	validation_1-logloss:0.64423
# [24]	validation_0-logloss:0.61945	validation_1-logloss:0.64082
# [25]	validation_0-logloss:0.61526	validation_1-logloss:0.63765
# [26]	validation_0-logloss:0.61114	validation_1-logloss:0.63430
# [27]	validation_0-logloss:0.60732	validation_1-logloss:0.63110
# [28]	validation_0-logloss:0.60343	validation_1-logloss:0.62765
# [29]	validation_0-logloss:0.59994	validation_1-logloss:0.62486
# [30]	validation_0-logloss:0.59670	validation_1-logloss:0.62209
# [31]	validation_0-logloss:0.59311	validation_1-logloss:0.61915
# [32]	validation_0-logloss:0.58939	validation_1-logloss:0.61604
# [33]	validation_0-logloss:0.58587	validation_1-logloss:0.61321
# [34]	validation_0-logloss:0.58231	validation_1-logloss:0.61044
# [35]	validation_0-logloss:0.57885	validation_1-logloss:0.60776
# [36]	validation_0-logloss:0.57572	validation_1-logloss:0.60522
# [37]	validation_0-logloss:0.57303	validation_1-logloss:0.60291
# [38]	validation_0-logloss:0.56985	validation_1-logloss:0.60054
# [39]	validation_0-logloss:0.56684	validation_1-logloss:0.59797
# [40]	validation_0-logloss:0.56386	validation_1-logloss:0.59551
# [41]	validation_0-logloss:0.56071	validation_1-logloss:0.59306
# [42]	validation_0-logloss:0.55778	validation_1-logloss:0.59089
# [43]	validation_0-logloss:0.55493	validation_1-logloss:0.58866
# [44]	validation_0-logloss:0.55212	validation_1-logloss:0.58639
# [45]	validation_0-logloss:0.54931	validation_1-logloss:0.58421
# [46]	validation_0-logloss:0.54721	validation_1-logloss:0.58255
# [47]	validation_0-logloss:0.54458	validation_1-logloss:0.58052
# [48]	validation_0-logloss:0.54211	validation_1-logloss:0.57872
# [49]	validation_0-logloss:0.53941	validation_1-logloss:0.57670
# [50]	validation_0-logloss:0.53702	validation_1-logloss:0.57485
# [51]	validation_0-logloss:0.53465	validation_1-logloss:0.57310
# [52]	validation_0-logloss:0.53220	validation_1-logloss:0.57122
# [53]	validation_0-logloss:0.52983	validation_1-logloss:0.56944
# [54]	validation_0-logloss:0.52754	validation_1-logloss:0.56785
# [55]	validation_0-logloss:0.52514	validation_1-logloss:0.56605
# [56]	validation_0-logloss:0.52295	validation_1-logloss:0.56444
# [57]	validation_0-logloss:0.52057	validation_1-logloss:0.56263
# [58]	validation_0-logloss:0.51844	validation_1-logloss:0.56103
# [59]	validation_0-logloss:0.51638	validation_1-logloss:0.55970
# [60]	validation_0-logloss:0.51437	validation_1-logloss:0.55805
# [61]	validation_0-logloss:0.51232	validation_1-logloss:0.55653
# [62]	validation_0-logloss:0.51037	validation_1-logloss:0.55529
# [63]	validation_0-logloss:0.50817	validation_1-logloss:0.55361
# [64]	validation_0-logloss:0.50643	validation_1-logloss:0.55234
# [65]	validation_0-logloss:0.50441	validation_1-logloss:0.55086
# [66]	validation_0-logloss:0.50241	validation_1-logloss:0.54952
# [67]	validation_0-logloss:0.50085	validation_1-logloss:0.54840
# [68]	validation_0-logloss:0.49907	validation_1-logloss:0.54702
# [69]	validation_0-logloss:0.49726	validation_1-logloss:0.54580
# [70]	validation_0-logloss:0.49550	validation_1-logloss:0.54466
# [71]	validation_0-logloss:0.49374	validation_1-logloss:0.54335
# [72]	validation_0-logloss:0.49178	validation_1-logloss:0.54214
# [73]	validation_0-logloss:0.48999	validation_1-logloss:0.54096
# [74]	validation_0-logloss:0.48848	validation_1-logloss:0.53992
# [75]	validation_0-logloss:0.48663	validation_1-logloss:0.53873
# [76]	validation_0-logloss:0.48499	validation_1-logloss:0.53749
# [77]	validation_0-logloss:0.48361	validation_1-logloss:0.53642
# [78]	validation_0-logloss:0.48223	validation_1-logloss:0.53539
# [79]	validation_0-logloss:0.48062	validation_1-logloss:0.53413
# [80]	validation_0-logloss:0.47910	validation_1-logloss:0.53319
# [81]	validation_0-logloss:0.47753	validation_1-logloss:0.53223
# [82]	validation_0-logloss:0.47598	validation_1-logloss:0.53106
# [83]	validation_0-logloss:0.47468	validation_1-logloss:0.53014
# [84]	validation_0-logloss:0.47312	validation_1-logloss:0.52917
# [85]	validation_0-logloss:0.47188	validation_1-logloss:0.52828
# [86]	validation_0-logloss:0.47055	validation_1-logloss:0.52732
# [87]	validation_0-logloss:0.46918	validation_1-logloss:0.52635
# [88]	validation_0-logloss:0.46783	validation_1-logloss:0.52547
# [89]	validation_0-logloss:0.46638	validation_1-logloss:0.52439
# [90]	validation_0-logloss:0.46523	validation_1-logloss:0.52357
# [91]	validation_0-logloss:0.46385	validation_1-logloss:0.52263
# [92]	validation_0-logloss:0.46275	validation_1-logloss:0.52181
# [93]	validation_0-logloss:0.46149	validation_1-logloss:0.52101
# [94]	validation_0-logloss:0.46040	validation_1-logloss:0.52033
# [95]	validation_0-logloss:0.45914	validation_1-logloss:0.51951
# [96]	validation_0-logloss:0.45798	validation_1-logloss:0.51876
# [97]	validation_0-logloss:0.45687	validation_1-logloss:0.51806
# [98]	validation_0-logloss:0.45584	validation_1-logloss:0.51741
# [99]	validation_0-logloss:0.45458	validation_1-logloss:0.51661
# [100]	validation_0-logloss:0.45352	validation_1-logloss:0.51596
# [101]	validation_0-logloss:0.45225	validation_1-logloss:0.51519
# [102]	validation_0-logloss:0.45132	validation_1-logloss:0.51462
# [103]	validation_0-logloss:0.45036	validation_1-logloss:0.51403
# [104]	validation_0-logloss:0.44910	validation_1-logloss:0.51333
# [105]	validation_0-logloss:0.44828	validation_1-logloss:0.51275
# [106]	validation_0-logloss:0.44736	validation_1-logloss:0.51218
# [107]	validation_0-logloss:0.44610	validation_1-logloss:0.51140
# [108]	validation_0-logloss:0.44480	validation_1-logloss:0.51059
# [109]	validation_0-logloss:0.44401	validation_1-logloss:0.51021
# [110]	validation_0-logloss:0.44281	validation_1-logloss:0.50946
# [111]	validation_0-logloss:0.44166	validation_1-logloss:0.50897
# [112]	validation_0-logloss:0.44087	validation_1-logloss:0.50850
# [113]	validation_0-logloss:0.44012	validation_1-logloss:0.50804
# [114]	validation_0-logloss:0.43908	validation_1-logloss:0.50728
# [115]	validation_0-logloss:0.43797	validation_1-logloss:0.50649
# [116]	validation_0-logloss:0.43708	validation_1-logloss:0.50588
# [117]	validation_0-logloss:0.43618	validation_1-logloss:0.50533
# [118]	validation_0-logloss:0.43508	validation_1-logloss:0.50456
# [119]	validation_0-logloss:0.43410	validation_1-logloss:0.50395
# [120]	validation_0-logloss:0.43311	validation_1-logloss:0.50338
# [121]	validation_0-logloss:0.43217	validation_1-logloss:0.50281
# [122]	validation_0-logloss:0.43125	validation_1-logloss:0.50215
# [123]	validation_0-logloss:0.43042	validation_1-logloss:0.50171
# [124]	validation_0-logloss:0.42984	validation_1-logloss:0.50140
# [125]	validation_0-logloss:0.42893	validation_1-logloss:0.50087
# [126]	validation_0-logloss:0.42822	validation_1-logloss:0.50043
# [127]	validation_0-logloss:0.42739	validation_1-logloss:0.49992
# [128]	validation_0-logloss:0.42638	validation_1-logloss:0.49941
# [129]	validation_0-logloss:0.42567	validation_1-logloss:0.49896
# [130]	validation_0-logloss:0.42478	validation_1-logloss:0.49847
# [131]	validation_0-logloss:0.42376	validation_1-logloss:0.49799
# [132]	validation_0-logloss:0.42279	validation_1-logloss:0.49743
# [133]	validation_0-logloss:0.42193	validation_1-logloss:0.49706
# [134]	validation_0-logloss:0.42114	validation_1-logloss:0.49662
# [135]	validation_0-logloss:0.42047	validation_1-logloss:0.49617
# [136]	validation_0-logloss:0.41949	validation_1-logloss:0.49566
# [137]	validation_0-logloss:0.41889	validation_1-logloss:0.49530
# [138]	validation_0-logloss:0.41830	validation_1-logloss:0.49495
# [139]	validation_0-logloss:0.41747	validation_1-logloss:0.49453
# [140]	validation_0-logloss:0.41680	validation_1-logloss:0.49413
# [141]	validation_0-logloss:0.41611	validation_1-logloss:0.49375
# [142]	validation_0-logloss:0.41501	validation_1-logloss:0.49317
# [143]	validation_0-logloss:0.41447	validation_1-logloss:0.49286
# [144]	validation_0-logloss:0.41394	validation_1-logloss:0.49259
# [145]	validation_0-logloss:0.41316	validation_1-logloss:0.49216
# [146]	validation_0-logloss:0.41234	validation_1-logloss:0.49174
# [147]	validation_0-logloss:0.41158	validation_1-logloss:0.49128
# [148]	validation_0-logloss:0.41095	validation_1-logloss:0.49094
# [149]	validation_0-logloss:0.41014	validation_1-logloss:0.49056
# [150]	validation_0-logloss:0.40923	validation_1-logloss:0.49009
# [151]	validation_0-logloss:0.40828	validation_1-logloss:0.48951
# [152]	validation_0-logloss:0.40767	validation_1-logloss:0.48914
# [153]	validation_0-logloss:0.40690	validation_1-logloss:0.48879
# [154]	validation_0-logloss:0.40630	validation_1-logloss:0.48847
# [155]	validation_0-logloss:0.40544	validation_1-logloss:0.48789
# [156]	validation_0-logloss:0.40473	validation_1-logloss:0.48744
# [157]	validation_0-logloss:0.40397	validation_1-logloss:0.48703
# [158]	validation_0-logloss:0.40313	validation_1-logloss:0.48656
# [159]	validation_0-logloss:0.40251	validation_1-logloss:0.48629
# [160]	validation_0-logloss:0.40169	validation_1-logloss:0.48580
# [161]	validation_0-logloss:0.40098	validation_1-logloss:0.48539
# [162]	validation_0-logloss:0.40041	validation_1-logloss:0.48508
# [163]	validation_0-logloss:0.39964	validation_1-logloss:0.48474
# [164]	validation_0-logloss:0.39912	validation_1-logloss:0.48443
# [165]	validation_0-logloss:0.39817	validation_1-logloss:0.48411
# [166]	validation_0-logloss:0.39742	validation_1-logloss:0.48369
# [167]	validation_0-logloss:0.39684	validation_1-logloss:0.48335
# [168]	validation_0-logloss:0.39615	validation_1-logloss:0.48303
# [169]	validation_0-logloss:0.39545	validation_1-logloss:0.48265
# [170]	validation_0-logloss:0.39497	validation_1-logloss:0.48234
# [171]	validation_0-logloss:0.39419	validation_1-logloss:0.48194
# [172]	validation_0-logloss:0.39346	validation_1-logloss:0.48156
# [173]	validation_0-logloss:0.39296	validation_1-logloss:0.48138
# [174]	validation_0-logloss:0.39242	validation_1-logloss:0.48111
# [175]	validation_0-logloss:0.39184	validation_1-logloss:0.48078
# [176]	validation_0-logloss:0.39110	validation_1-logloss:0.48042
# [177]	validation_0-logloss:0.39042	validation_1-logloss:0.48009
# [178]	validation_0-logloss:0.38953	validation_1-logloss:0.47958
# [179]	validation_0-logloss:0.38895	validation_1-logloss:0.47931
# [180]	validation_0-logloss:0.38828	validation_1-logloss:0.47894
# [181]	validation_0-logloss:0.38736	validation_1-logloss:0.47857
# [182]	validation_0-logloss:0.38678	validation_1-logloss:0.47829
# [183]	validation_0-logloss:0.38609	validation_1-logloss:0.47794
# [184]	validation_0-logloss:0.38551	validation_1-logloss:0.47763
# [185]	validation_0-logloss:0.38488	validation_1-logloss:0.47733
# [186]	validation_0-logloss:0.38430	validation_1-logloss:0.47697
# [187]	validation_0-logloss:0.38367	validation_1-logloss:0.47659
# [188]	validation_0-logloss:0.38299	validation_1-logloss:0.47624
# [189]	validation_0-logloss:0.38241	validation_1-logloss:0.47594
# [190]	validation_0-logloss:0.38207	validation_1-logloss:0.47578
# [191]	validation_0-logloss:0.38148	validation_1-logloss:0.47548
# [192]	validation_0-logloss:0.38098	validation_1-logloss:0.47525
# [193]	validation_0-logloss:0.38057	validation_1-logloss:0.47498
# [194]	validation_0-logloss:0.37994	validation_1-logloss:0.47472
# [195]	validation_0-logloss:0.37943	validation_1-logloss:0.47444
# [196]	validation_0-logloss:0.37885	validation_1-logloss:0.47414
# [197]	validation_0-logloss:0.37836	validation_1-logloss:0.47388
# [198]	validation_0-logloss:0.37766	validation_1-logloss:0.47358
# [199]	validation_0-logloss:0.37696	validation_1-logloss:0.47329
# [200]	validation_0-logloss:0.37632	validation_1-logloss:0.47300
# [201]	validation_0-logloss:0.37580	validation_1-logloss:0.47269
# [202]	validation_0-logloss:0.37503	validation_1-logloss:0.47238
# [203]	validation_0-logloss:0.37412	validation_1-logloss:0.47198
# [204]	validation_0-logloss:0.37363	validation_1-logloss:0.47169
# [205]	validation_0-logloss:0.37314	validation_1-logloss:0.47149
# [206]	validation_0-logloss:0.37250	validation_1-logloss:0.47122
# [207]	validation_0-logloss:0.37188	validation_1-logloss:0.47087
# [208]	validation_0-logloss:0.37153	validation_1-logloss:0.47064
# [209]	validation_0-logloss:0.37074	validation_1-logloss:0.47024
# [210]	validation_0-logloss:0.37033	validation_1-logloss:0.47012
# [211]	validation_0-logloss:0.36982	validation_1-logloss:0.46983
# [212]	validation_0-logloss:0.36904	validation_1-logloss:0.46945
# [213]	validation_0-logloss:0.36858	validation_1-logloss:0.46922
# [214]	validation_0-logloss:0.36819	validation_1-logloss:0.46913
# [215]	validation_0-logloss:0.36793	validation_1-logloss:0.46896
# [216]	validation_0-logloss:0.36731	validation_1-logloss:0.46876
# [217]	validation_0-logloss:0.36698	validation_1-logloss:0.46858
# [218]	validation_0-logloss:0.36651	validation_1-logloss:0.46842
# [219]	validation_0-logloss:0.36624	validation_1-logloss:0.46828
# [220]	validation_0-logloss:0.36569	validation_1-logloss:0.46806
# [221]	validation_0-logloss:0.36514	validation_1-logloss:0.46779
# [222]	validation_0-logloss:0.36469	validation_1-logloss:0.46758
# [223]	validation_0-logloss:0.36409	validation_1-logloss:0.46729
# [224]	validation_0-logloss:0.36354	validation_1-logloss:0.46700
# [225]	validation_0-logloss:0.36322	validation_1-logloss:0.46687
# [226]	validation_0-logloss:0.36290	validation_1-logloss:0.46675
# [227]	validation_0-logloss:0.36237	validation_1-logloss:0.46645
# [228]	validation_0-logloss:0.36197	validation_1-logloss:0.46635
# [229]	validation_0-logloss:0.36145	validation_1-logloss:0.46608
# [230]	validation_0-logloss:0.36088	validation_1-logloss:0.46574
# [231]	validation_0-logloss:0.36028	validation_1-logloss:0.46555
# [232]	validation_0-logloss:0.35978	validation_1-logloss:0.46537
# [233]	validation_0-logloss:0.35940	validation_1-logloss:0.46525
# [234]	validation_0-logloss:0.35903	validation_1-logloss:0.46507
# [235]	validation_0-logloss:0.35840	validation_1-logloss:0.46484
# [236]	validation_0-logloss:0.35777	validation_1-logloss:0.46449
# [237]	validation_0-logloss:0.35727	validation_1-logloss:0.46432
# [238]	validation_0-logloss:0.35688	validation_1-logloss:0.46423
# [239]	validation_0-logloss:0.35621	validation_1-logloss:0.46390
# [240]	validation_0-logloss:0.35578	validation_1-logloss:0.46371
# [241]	validation_0-logloss:0.35509	validation_1-logloss:0.46335
# [242]	validation_0-logloss:0.35464	validation_1-logloss:0.46315
# [243]	validation_0-logloss:0.35441	validation_1-logloss:0.46306
# [244]	validation_0-logloss:0.35392	validation_1-logloss:0.46288
# [245]	validation_0-logloss:0.35320	validation_1-logloss:0.46253
# [246]	validation_0-logloss:0.35272	validation_1-logloss:0.46239
# [247]	validation_0-logloss:0.35229	validation_1-logloss:0.46228
# [248]	validation_0-logloss:0.35187	validation_1-logloss:0.46202
# [249]	validation_0-logloss:0.35138	validation_1-logloss:0.46183
# [250]	validation_0-logloss:0.35093	validation_1-logloss:0.46162
# [251]	validation_0-logloss:0.35053	validation_1-logloss:0.46141
# [252]	validation_0-logloss:0.35013	validation_1-logloss:0.46121
# [253]	validation_0-logloss:0.34985	validation_1-logloss:0.46110
# [254]	validation_0-logloss:0.34927	validation_1-logloss:0.46080
# [255]	validation_0-logloss:0.34893	validation_1-logloss:0.46066
# [256]	validation_0-logloss:0.34879	validation_1-logloss:0.46061
# [257]	validation_0-logloss:0.34848	validation_1-logloss:0.46047
# [258]	validation_0-logloss:0.34797	validation_1-logloss:0.46025
# [259]	validation_0-logloss:0.34767	validation_1-logloss:0.46012
# [260]	validation_0-logloss:0.34730	validation_1-logloss:0.45998
# [261]	validation_0-logloss:0.34683	validation_1-logloss:0.45974
# [262]	validation_0-logloss:0.34645	validation_1-logloss:0.45963
# [263]	validation_0-logloss:0.34594	validation_1-logloss:0.45936
# [264]	validation_0-logloss:0.34583	validation_1-logloss:0.45941
# [265]	validation_0-logloss:0.34534	validation_1-logloss:0.45916
# [266]	validation_0-logloss:0.34451	validation_1-logloss:0.45875
# [267]	validation_0-logloss:0.34410	validation_1-logloss:0.45858
# [268]	validation_0-logloss:0.34364	validation_1-logloss:0.45838
# [269]	validation_0-logloss:0.34324	validation_1-logloss:0.45818
# [270]	validation_0-logloss:0.34308	validation_1-logloss:0.45815
# [271]	validation_0-logloss:0.34285	validation_1-logloss:0.45809
# [272]	validation_0-logloss:0.34234	validation_1-logloss:0.45778
# [273]	validation_0-logloss:0.34197	validation_1-logloss:0.45758
# [274]	validation_0-logloss:0.34148	validation_1-logloss:0.45747
# [275]	validation_0-logloss:0.34099	validation_1-logloss:0.45727
# [276]	validation_0-logloss:0.34064	validation_1-logloss:0.45706
# [277]	validation_0-logloss:0.33996	validation_1-logloss:0.45685
# [278]	validation_0-logloss:0.33952	validation_1-logloss:0.45671
# [279]	validation_0-logloss:0.33904	validation_1-logloss:0.45645
# [280]	validation_0-logloss:0.33876	validation_1-logloss:0.45638
# [281]	validation_0-logloss:0.33830	validation_1-logloss:0.45616
# [282]	validation_0-logloss:0.33807	validation_1-logloss:0.45610
# [283]	validation_0-logloss:0.33773	validation_1-logloss:0.45599
# [284]	validation_0-logloss:0.33753	validation_1-logloss:0.45595
# [285]	validation_0-logloss:0.33680	validation_1-logloss:0.45569
# [286]	validation_0-logloss:0.33647	validation_1-logloss:0.45561
# [287]	validation_0-logloss:0.33587	validation_1-logloss:0.45537
# [288]	validation_0-logloss:0.33540	validation_1-logloss:0.45517
# [289]	validation_0-logloss:0.33512	validation_1-logloss:0.45506
# [290]	validation_0-logloss:0.33487	validation_1-logloss:0.45493
# [291]	validation_0-logloss:0.33442	validation_1-logloss:0.45477
# [292]	validation_0-logloss:0.33428	validation_1-logloss:0.45475
# [293]	validation_0-logloss:0.33403	validation_1-logloss:0.45465
# [294]	validation_0-logloss:0.33388	validation_1-logloss:0.45457
# [295]	validation_0-logloss:0.33364	validation_1-logloss:0.45447
# [296]	validation_0-logloss:0.33346	validation_1-logloss:0.45439
# [297]	validation_0-logloss:0.33297	validation_1-logloss:0.45423
# [298]	validation_0-logloss:0.33249	validation_1-logloss:0.45407
# [299]	validation_0-logloss:0.33213	validation_1-logloss:0.45395
# [300]	validation_0-logloss:0.33178	validation_1-logloss:0.45375
# [301]	validation_0-logloss:0.33142	validation_1-logloss:0.45360
# [302]	validation_0-logloss:0.33095	validation_1-logloss:0.45341
# [303]	validation_0-logloss:0.33038	validation_1-logloss:0.45319
# [304]	validation_0-logloss:0.32986	validation_1-logloss:0.45298
# [305]	validation_0-logloss:0.32945	validation_1-logloss:0.45278
# [306]	validation_0-logloss:0.32907	validation_1-logloss:0.45262
# [307]	validation_0-logloss:0.32887	validation_1-logloss:0.45256
# [308]	validation_0-logloss:0.32850	validation_1-logloss:0.45254
# [309]	validation_0-logloss:0.32817	validation_1-logloss:0.45244
# [310]	validation_0-logloss:0.32773	validation_1-logloss:0.45226
# [311]	validation_0-logloss:0.32745	validation_1-logloss:0.45213
# [312]	validation_0-logloss:0.32709	validation_1-logloss:0.45196
# [313]	validation_0-logloss:0.32646	validation_1-logloss:0.45169
# [314]	validation_0-logloss:0.32613	validation_1-logloss:0.45156
# [315]	validation_0-logloss:0.32579	validation_1-logloss:0.45151
# [316]	validation_0-logloss:0.32556	validation_1-logloss:0.45147
# [317]	validation_0-logloss:0.32503	validation_1-logloss:0.45131
# [318]	validation_0-logloss:0.32456	validation_1-logloss:0.45119
# [319]	validation_0-logloss:0.32426	validation_1-logloss:0.45112
# [320]	validation_0-logloss:0.32384	validation_1-logloss:0.45090
# [321]	validation_0-logloss:0.32353	validation_1-logloss:0.45077
# [322]	validation_0-logloss:0.32288	validation_1-logloss:0.45053
# [323]	validation_0-logloss:0.32242	validation_1-logloss:0.45034
# [324]	validation_0-logloss:0.32214	validation_1-logloss:0.45018
# [325]	validation_0-logloss:0.32163	validation_1-logloss:0.44996
# [326]	validation_0-logloss:0.32130	validation_1-logloss:0.44984
# [327]	validation_0-logloss:0.32075	validation_1-logloss:0.44966
# [328]	validation_0-logloss:0.32033	validation_1-logloss:0.44948
# [329]	validation_0-logloss:0.31982	validation_1-logloss:0.44930
# [330]	validation_0-logloss:0.31938	validation_1-logloss:0.44908
# [331]	validation_0-logloss:0.31915	validation_1-logloss:0.44901
# [332]	validation_0-logloss:0.31890	validation_1-logloss:0.44894
# [333]	validation_0-logloss:0.31823	validation_1-logloss:0.44869
# [334]	validation_0-logloss:0.31802	validation_1-logloss:0.44865
# [335]	validation_0-logloss:0.31775	validation_1-logloss:0.44856
# [336]	validation_0-logloss:0.31738	validation_1-logloss:0.44848
# [337]	validation_0-logloss:0.31685	validation_1-logloss:0.44817
# [338]	validation_0-logloss:0.31633	validation_1-logloss:0.44796
# [339]	validation_0-logloss:0.31608	validation_1-logloss:0.44788
# [340]	validation_0-logloss:0.31590	validation_1-logloss:0.44782
# [341]	validation_0-logloss:0.31559	validation_1-logloss:0.44766
# [342]	validation_0-logloss:0.31507	validation_1-logloss:0.44749
# [343]	validation_0-logloss:0.31474	validation_1-logloss:0.44727
# [344]	validation_0-logloss:0.31462	validation_1-logloss:0.44722
# [345]	validation_0-logloss:0.31413	validation_1-logloss:0.44707
# [346]	validation_0-logloss:0.31390	validation_1-logloss:0.44698
# [347]	validation_0-logloss:0.31354	validation_1-logloss:0.44684
# [348]	validation_0-logloss:0.31326	validation_1-logloss:0.44664
# [349]	validation_0-logloss:0.31307	validation_1-logloss:0.44656
# [350]	validation_0-logloss:0.31287	validation_1-logloss:0.44647
# [351]	validation_0-logloss:0.31257	validation_1-logloss:0.44635
# [352]	validation_0-logloss:0.31201	validation_1-logloss:0.44605
# [353]	validation_0-logloss:0.31155	validation_1-logloss:0.44579
# [354]	validation_0-logloss:0.31141	validation_1-logloss:0.44574
# [355]	validation_0-logloss:0.31115	validation_1-logloss:0.44558
# [356]	validation_0-logloss:0.31066	validation_1-logloss:0.44535
# [357]	validation_0-logloss:0.31048	validation_1-logloss:0.44528
# [358]	validation_0-logloss:0.31005	validation_1-logloss:0.44511
# [359]	validation_0-logloss:0.30954	validation_1-logloss:0.44488
# [360]	validation_0-logloss:0.30921	validation_1-logloss:0.44472
# [361]	validation_0-logloss:0.30903	validation_1-logloss:0.44470
# [362]	validation_0-logloss:0.30873	validation_1-logloss:0.44464
# [363]	validation_0-logloss:0.30825	validation_1-logloss:0.44447
# [364]	validation_0-logloss:0.30810	validation_1-logloss:0.44443
# [365]	validation_0-logloss:0.30778	validation_1-logloss:0.44424
# [366]	validation_0-logloss:0.30747	validation_1-logloss:0.44410
# [367]	validation_0-logloss:0.30715	validation_1-logloss:0.44392
# [368]	validation_0-logloss:0.30677	validation_1-logloss:0.44375
# [369]	validation_0-logloss:0.30623	validation_1-logloss:0.44352
# [370]	validation_0-logloss:0.30604	validation_1-logloss:0.44346
# [371]	validation_0-logloss:0.30580	validation_1-logloss:0.44338
# [372]	validation_0-logloss:0.30539	validation_1-logloss:0.44328
# [373]	validation_0-logloss:0.30498	validation_1-logloss:0.44317
# [374]	validation_0-logloss:0.30449	validation_1-logloss:0.44292
# [375]	validation_0-logloss:0.30421	validation_1-logloss:0.44276
# [376]	validation_0-logloss:0.30392	validation_1-logloss:0.44266
# [377]	validation_0-logloss:0.30370	validation_1-logloss:0.44262
# [378]	validation_0-logloss:0.30327	validation_1-logloss:0.44254
# [379]	validation_0-logloss:0.30282	validation_1-logloss:0.44240
# [380]	validation_0-logloss:0.30246	validation_1-logloss:0.44233
# [381]	validation_0-logloss:0.30212	validation_1-logloss:0.44227
# [382]	validation_0-logloss:0.30173	validation_1-logloss:0.44213
# [383]	validation_0-logloss:0.30152	validation_1-logloss:0.44203
# [384]	validation_0-logloss:0.30115	validation_1-logloss:0.44192
# [385]	validation_0-logloss:0.30098	validation_1-logloss:0.44186
# [386]	validation_0-logloss:0.30081	validation_1-logloss:0.44177
# [387]	validation_0-logloss:0.30063	validation_1-logloss:0.44174
# [388]	validation_0-logloss:0.30043	validation_1-logloss:0.44170
# [389]	validation_0-logloss:0.30005	validation_1-logloss:0.44147
# [390]	validation_0-logloss:0.29987	validation_1-logloss:0.44135
# [391]	validation_0-logloss:0.29965	validation_1-logloss:0.44126
# [392]	validation_0-logloss:0.29954	validation_1-logloss:0.44122
# [393]	validation_0-logloss:0.29937	validation_1-logloss:0.44118
# [394]	validation_0-logloss:0.29921	validation_1-logloss:0.44113
# [395]	validation_0-logloss:0.29883	validation_1-logloss:0.44100
# [396]	validation_0-logloss:0.29864	validation_1-logloss:0.44091
# [397]	validation_0-logloss:0.29818	validation_1-logloss:0.44075
# [398]	validation_0-logloss:0.29783	validation_1-logloss:0.44062
# [399]	validation_0-logloss:0.29738	validation_1-logloss:0.44049
# [400]	validation_0-logloss:0.29696	validation_1-logloss:0.44033
# [401]	validation_0-logloss:0.29667	validation_1-logloss:0.44018
# [402]	validation_0-logloss:0.29646	validation_1-logloss:0.44009
# [403]	validation_0-logloss:0.29622	validation_1-logloss:0.44002
# [404]	validation_0-logloss:0.29595	validation_1-logloss:0.43996
# [405]	validation_0-logloss:0.29572	validation_1-logloss:0.43988
# [406]	validation_0-logloss:0.29536	validation_1-logloss:0.43983
# [407]	validation_0-logloss:0.29518	validation_1-logloss:0.43977
# [408]	validation_0-logloss:0.29482	validation_1-logloss:0.43959
# [409]	validation_0-logloss:0.29450	validation_1-logloss:0.43953
# [410]	validation_0-logloss:0.29432	validation_1-logloss:0.43947
# [411]	validation_0-logloss:0.29426	validation_1-logloss:0.43946
# [412]	validation_0-logloss:0.29390	validation_1-logloss:0.43941
# [413]	validation_0-logloss:0.29346	validation_1-logloss:0.43929
# [414]	validation_0-logloss:0.29318	validation_1-logloss:0.43924
# [415]	validation_0-logloss:0.29274	validation_1-logloss:0.43899
# [416]	validation_0-logloss:0.29224	validation_1-logloss:0.43886
# [417]	validation_0-logloss:0.29205	validation_1-logloss:0.43885
# [418]	validation_0-logloss:0.29171	validation_1-logloss:0.43871
# [419]	validation_0-logloss:0.29151	validation_1-logloss:0.43865
# [420]	validation_0-logloss:0.29118	validation_1-logloss:0.43850
# [421]	validation_0-logloss:0.29081	validation_1-logloss:0.43838
# [422]	validation_0-logloss:0.29053	validation_1-logloss:0.43831
# [423]	validation_0-logloss:0.29024	validation_1-logloss:0.43820
# [424]	validation_0-logloss:0.29007	validation_1-logloss:0.43815
# [425]	validation_0-logloss:0.28969	validation_1-logloss:0.43804
# [426]	validation_0-logloss:0.28944	validation_1-logloss:0.43794
# [427]	validation_0-logloss:0.28910	validation_1-logloss:0.43781
# [428]	validation_0-logloss:0.28880	validation_1-logloss:0.43766
# [429]	validation_0-logloss:0.28858	validation_1-logloss:0.43755
# [430]	validation_0-logloss:0.28827	validation_1-logloss:0.43742
# [431]	validation_0-logloss:0.28795	validation_1-logloss:0.43729
# [432]	validation_0-logloss:0.28771	validation_1-logloss:0.43720
# [433]	validation_0-logloss:0.28731	validation_1-logloss:0.43702
# [434]	validation_0-logloss:0.28712	validation_1-logloss:0.43698
# [435]	validation_0-logloss:0.28681	validation_1-logloss:0.43687
# [436]	validation_0-logloss:0.28646	validation_1-logloss:0.43679
# [437]	validation_0-logloss:0.28629	validation_1-logloss:0.43671
# [438]	validation_0-logloss:0.28589	validation_1-logloss:0.43659
# [439]	validation_0-logloss:0.28577	validation_1-logloss:0.43656
# [440]	validation_0-logloss:0.28540	validation_1-logloss:0.43643
# [441]	validation_0-logloss:0.28513	validation_1-logloss:0.43631
# [442]	validation_0-logloss:0.28477	validation_1-logloss:0.43611
# [443]	validation_0-logloss:0.28454	validation_1-logloss:0.43605
# [444]	validation_0-logloss:0.28404	validation_1-logloss:0.43584
# [445]	validation_0-logloss:0.28368	validation_1-logloss:0.43571
# [446]	validation_0-logloss:0.28350	validation_1-logloss:0.43565
# [447]	validation_0-logloss:0.28332	validation_1-logloss:0.43558
# [448]	validation_0-logloss:0.28293	validation_1-logloss:0.43543
# [449]	validation_0-logloss:0.28261	validation_1-logloss:0.43532
# [450]	validation_0-logloss:0.28234	validation_1-logloss:0.43523
# [451]	validation_0-logloss:0.28226	validation_1-logloss:0.43523
# [452]	validation_0-logloss:0.28179	validation_1-logloss:0.43500
# [453]	validation_0-logloss:0.28145	validation_1-logloss:0.43490
# [454]	validation_0-logloss:0.28109	validation_1-logloss:0.43479
# [455]	validation_0-logloss:0.28068	validation_1-logloss:0.43469
# [456]	validation_0-logloss:0.28036	validation_1-logloss:0.43459
# [457]	validation_0-logloss:0.28010	validation_1-logloss:0.43456
# [458]	validation_0-logloss:0.27974	validation_1-logloss:0.43442
# [459]	validation_0-logloss:0.27945	validation_1-logloss:0.43428
# [460]	validation_0-logloss:0.27905	validation_1-logloss:0.43421
# [461]	validation_0-logloss:0.27876	validation_1-logloss:0.43414
# [462]	validation_0-logloss:0.27850	validation_1-logloss:0.43409
# [463]	validation_0-logloss:0.27814	validation_1-logloss:0.43401
# [464]	validation_0-logloss:0.27791	validation_1-logloss:0.43389
# [465]	validation_0-logloss:0.27745	validation_1-logloss:0.43374
# [466]	validation_0-logloss:0.27715	validation_1-logloss:0.43361
# [467]	validation_0-logloss:0.27677	validation_1-logloss:0.43344
# [468]	validation_0-logloss:0.27647	validation_1-logloss:0.43328
# [469]	validation_0-logloss:0.27605	validation_1-logloss:0.43318
# [470]	validation_0-logloss:0.27589	validation_1-logloss:0.43311
# [471]	validation_0-logloss:0.27561	validation_1-logloss:0.43297
# [472]	validation_0-logloss:0.27540	validation_1-logloss:0.43291
# [473]	validation_0-logloss:0.27506	validation_1-logloss:0.43279
# [474]	validation_0-logloss:0.27490	validation_1-logloss:0.43275
# [475]	validation_0-logloss:0.27459	validation_1-logloss:0.43264
# [476]	validation_0-logloss:0.27435	validation_1-logloss:0.43261
# [477]	validation_0-logloss:0.27397	validation_1-logloss:0.43247
# [478]	validation_0-logloss:0.27373	validation_1-logloss:0.43235
# [479]	validation_0-logloss:0.27348	validation_1-logloss:0.43224
# [480]	validation_0-logloss:0.27330	validation_1-logloss:0.43217
# [481]	validation_0-logloss:0.27298	validation_1-logloss:0.43206
# [482]	validation_0-logloss:0.27273	validation_1-logloss:0.43196
# [483]	validation_0-logloss:0.27233	validation_1-logloss:0.43173
# [484]	validation_0-logloss:0.27206	validation_1-logloss:0.43165
# [485]	validation_0-logloss:0.27189	validation_1-logloss:0.43159
# [486]	validation_0-logloss:0.27156	validation_1-logloss:0.43147
# [487]	validation_0-logloss:0.27144	validation_1-logloss:0.43147
# [488]	validation_0-logloss:0.27119	validation_1-logloss:0.43136
# [489]	validation_0-logloss:0.27091	validation_1-logloss:0.43130
# [490]	validation_0-logloss:0.27072	validation_1-logloss:0.43121
# [491]	validation_0-logloss:0.27058	validation_1-logloss:0.43114
# [492]	validation_0-logloss:0.27040	validation_1-logloss:0.43111
# [493]	validation_0-logloss:0.27018	validation_1-logloss:0.43106
# [494]	validation_0-logloss:0.27010	validation_1-logloss:0.43105
# [495]	validation_0-logloss:0.26986	validation_1-logloss:0.43099
# [496]	validation_0-logloss:0.26971	validation_1-logloss:0.43100
# [497]	validation_0-logloss:0.26957	validation_1-logloss:0.43091
# [498]	validation_0-logloss:0.26937	validation_1-logloss:0.43083
# [499]	validation_0-logloss:0.26909	validation_1-logloss:0.43074
# Attack Model Accuracy on train set: 0.974125
# Attack Model Accuracy on test set: 0.8458333333333333

# %% [markdown]
# # Target Model

# %%
# load the target model
MODEL_PATH = '/content/drive/My Drive/Colab Notebooks/attack/models/resnet34_cifar10.pth'

device=torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

target_model = resnet34(num_classes=10).to(device)

state_dict = torch.load(MODEL_PATH, map_location=device)
target_model.load_state_dict(state_dict['net'])

print(target_model)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (3): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (4): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (5): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (2): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
# loading evaluation data
with open('/content/drive/My Drive/Colab Notebooks/attack/pickle/cifar10/resnet34/eval.p', 'rb') as f:
    eval_dataset = pickle.load(f)

# prepare the data for the evaluation
eval_images = [item[0] for item in eval_dataset]
eval_labels = [item[1] for item in eval_dataset]
eval_membership_status = [item[2] for item in eval_dataset]

eval_images_tensor = torch.stack(eval_images)
eval_labels_tensor = torch.tensor(eval_labels)
eval_dataset_tensor = TensorDataset(eval_images_tensor, eval_labels_tensor)
eval_loader = DataLoader(eval_dataset_tensor, batch_size=64, shuffle=False, num_workers=2)

# %%
#  Generate evaluation data for attack model using target model
probabilities = []
target_model.eval()
with torch.no_grad():
    for inputs, _ in eval_loader:
        inputs = inputs.to(device)
        outputs = target_model(inputs)
        probs = torch.softmax(outputs, dim=1)
        probabilities.extend(probs.cpu().numpy())

X_eval = np.array(probabilities)
y_eval_true = np.array(eval_membership_status)

# %%
# evaluate the attack model
y_eval_pred = attack_model.predict(X_eval)
accuracy = accuracy_score(y_eval_true, y_eval_pred)
print(f"Membership Inference Accuracy on evaluation data: {accuracy}")
# Out:
# Membership Inference Accuracy on evaluation data: 0.745

# %%
joblib.dump(attack_model, '/content/drive/My Drive/Colab Notebooks/attack/attack_models/cifar10_resnet/attack_model_74.pkl')
# Out:
# ['/content/drive/My Drive/Colab Notebooks/attack/attack_models/cifar10_resnet/attack_model_74.pkl']
